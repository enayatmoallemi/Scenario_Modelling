# %%
import sys
sys.path.append(r'C:\Users\moallemie\EMAworkbench-master')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from ema_workbench import load_results, ema_logging

# %%
sc = 3000    # Specify the number of scenarios where the convergence in the SA indices occured
n_exp = 2000  # Indicate the number of LHS experiments to run 
t = 2030
nprocess = 25

# %% [markdown]
# ## Load  model, uncertainities; generate initial experiments

# %%
# Open Excel input data from the notebook directory before runnign the code in multi-processing.

def create_sets(outcome_var):
    
    from Model_init import vensimModel
    
    directory = 'D:/moallemie/GitHub/Scenario_Modelling/Model/'

    df_unc = pd.read_excel(directory+'ScenarioFramework.xlsx', sheet_name='Uncertainties')

    # 0.75/1.25 multiplication is added to Min/Max for parameters with Reference values 0 
    #or min/max manually set in the spreadsheet   
    #df_unc['Min'] = df_unc['Min'] + df_unc['Reference'] * 0.75
    #df_unc['Max'] = df_unc['Max'] + df_unc['Reference'] * 1.25



    # From the Scenario Framework (all uncertainties), filter only those top 20 sensitive uncertainties under each outcome
    sa_dir='D:/moallemie/GitHub/Scenario_Modelling/Results/Morris_results/'

    mu_df = pd.read_csv(sa_dir+"MorrisIndices_{}_sc{}_t{}_test.csv".format(outcome_var, sc, t))
    mu_df.rename(columns={'Unnamed: 0': 'Uncertainty'}, inplace=True)
    mu_df.sort_values(by=['mu_star'], ascending=False, inplace=True)
    mu_df = mu_df.head(20)
    mu_unc = mu_df['Uncertainty']
    mu_unc_df = mu_unc.to_frame()

    # Remove the rest of insensitive uncertainties from the Scenario Framework and update df_unc
    keys = list(mu_unc_df.columns.values)
    i1 = df_unc.set_index(keys).index
    i2 = mu_unc_df.set_index(keys).index
    df_unc2 = df_unc[i1.isin(i2)]


    # Reorder the dataframe of mu index according to the model uncertainty.
    # It will be used when we generate Sets 1 & 2 
    mu_df1 = mu_df[['Uncertainty', 'mu_star']]
    mu_df1 = mu_df1.set_index('Uncertainty')
    mu_df1 = mu_df1.reindex(index=df_unc2['Uncertainty'])
    mu_df1 = mu_df1.reset_index()


    vensimModel.uncertainties = [RealParameter(row['Uncertainty'], row['Min'], row['Max']) for index, row in df_unc2.iterrows()]

    df_out = pd.read_excel(directory+'ScenarioFramework.xlsx', sheet_name='Outcomes')
    vensimModel.outcomes = [TimeSeriesOutcome(out) for out in df_out['Outcome']]



    from ema_workbench import MultiprocessingEvaluator
    from ema_workbench.em_framework.evaluators import (MC, LHS, FAST, FF, PFF, SOBOL, MORRIS)

    try:
        with MultiprocessingEvaluator(vensimModel, n_processes=nprocess) as evaluator:
            results = evaluator.perform_experiments(scenarios=n_exp, uncertainty_sampling=LHS) # The number of scenarios here is only for identifying the number of important parameters in SA results.
    except (BrokenPipeError, IOError):
        pass

    experiments, outcomes = results


    # Sort factors by importance
    inds_mu = mu_df1['mu_star'].values
    factors_sorted = np.argsort(inds_mu)[::-1]

    # Set up DataFrame of default values to use for experiment
    nsamples = len(experiments.index)

    defaultvalues = df_unc2['Reference'].values
    X_defaults = np.tile(defaultvalues,(nsamples, 1))


    # Create Set 1 from experiments
    exp_T = experiments.drop(['scenario', 'policy', 'model'], axis=1).T.reindex(df_unc2['Uncertainty'])
    exp_ordered = exp_T.T
    X_Set1 = exp_ordered.values

    # Create initial Sets 2 and 3
    X_Set2 = np.copy(X_defaults)
    X_Set3 = np.copy(X_Set1)

    return df_unc2, factors_sorted, X_defaults, X_Set1, X_Set2, X_Set3, outcomes, mu_df

# %% [markdown]
# ## Where to draw the line between important and not important?

# %%
'''
Modifed from Waterprogramming blog by Antonia Hadgimichael: https://github.com/antonia-had/SA_verification

The idea is that we create 2 additiopnal Sets (current SA samples are Set 1).

We create a Set 2, using only the T most important factors from our Set 1 sample, 
and fixing all other factors to their default values.

We also create a Set 3, now fixing the T most important factors to defaults 
and using the sampled values of all other factors from Set 1.

If we classified our important and unimportant factors correctly, 
then the correlation coefficient between the model outputs of Set 2 and Set 1 should approximate 1 
(since we’re fixing all factors that don’t matter), 
and the correlation coefficient between outputs from Set 3 and Set 1 should approximate 0 
(since the factors we sampled are inconsequential to the output).

'''
# Out:
# '\nModifed from Waterprogramming blog by Antonia Hadgimichael: https://github.com/antonia-had/SA_verification\n\nThe idea is that we create 2 additiopnal Sets (current SA samples are Set 1).\n\nWe create a Set 2, using only the T most important factors from our Set 1 sample, \nand fixing all other factors to their default values.\n\nWe also create a Set 3, now fixing the T most important factors to defaults \nand using the sampled values of all other factors from Set 1.\n\nIf we classified our important and unimportant factors correctly, \nthen the correlation coefficient between the model outputs of Set 2 and Set 1 should approximate 1 \n(since we’re fixing all factors that don’t matter), \nand the correlation coefficient between outputs from Set 3 and Set 1 should approximate 0 \n(since the factors we sampled are inconsequential to the output).\n\n'

# %%
# Define a function to convert your Set 2 and Set 3 into experiments structure in the EMA Workbench

def SA_experiments_to_scenarios(experiments, top_unc, model=None):
    '''

    "Slighlty modifed from the EMA Workbench"
    
    This function transform a structured experiments array into a list
    of Scenarios.

    If model is provided, the uncertainties of the model are used.
    Otherwise, it is assumed that all non-default columns are
    uncertainties.

    Parameters
    ----------
    experiments : numpy structured array
                  a structured array containing experiments
    model : ModelInstance, optional

    Returns
    -------
    a list of Scenarios

    '''
    from ema_workbench import Scenario
    
    # get the names of top 20 uncertainties
    uncertainties = list(top_unc['Uncertainty'])

    # make list of of tuples of tuples
    cases = []
    cache = set()
    for i in range(experiments.shape[0]):
        case = {}
        case_tuple = []
        for uncertainty in uncertainties:
            entry = experiments[uncertainty][i]
            case[uncertainty] = entry
            case_tuple.append(entry)

        case_tuple = tuple(case_tuple)
        cases.append(case)
        cache.add((case_tuple))

    scenarios = [Scenario(**entry) for entry in cases]

    return scenarios

# %% [markdown]
# # Run the models for the top n factors in Set 2 and Set 3 and generate correlation figures
#
# def ranking_verification(outcome_var, df_unc2, factors_sorted, X_defaults, X_Set1, X_Set2, X_Set3, outcomes):
#
#     from Model_init import vensimModel
#
#     coefficient_S1_S2 = 0
#     coefficient_S1_S3 = 0.99
#
#     n = 0
#     for f in range(1, len(factors_sorted)+1):
#         ntopfactors = f
#         if (coefficient_S1_S2 <=0.95 or coefficient_S1_S3 >= 0.1):
#
#             for i in range(ntopfactors): #Loop through all important factors
#                 X_Set2[:,factors_sorted[i]] = X_Set1[:,factors_sorted[i]] #Fix use samples for important
#                 X_Set3[:,factors_sorted[i]] = X_defaults[:,factors_sorted[i]] #Fix important to defaults
#
#             X_Set2_exp = pd.DataFrame(data=X_Set2, columns=df_unc2['Uncertainty'].tolist())
#             X_Set3_exp = pd.DataFrame(data=X_Set3, columns=df_unc2['Uncertainty'].tolist())
#
#             scenarios_Set2 = SA_experiments_to_scenarios(X_Set2_exp, df_unc2, model=vensimModel)
#             scenarios_Set3 = SA_experiments_to_scenarios(X_Set3_exp, df_unc2, model=vensimModel)
#
#             vensimModel.outcomes = [TimeSeriesOutcome(outcome_var)]
#
#             with MultiprocessingEvaluator(vensimModel, n_processes=nprocess) as evaluator:
#                     experiments_Set2, outcomes_Set2 = evaluator.perform_experiments(scenarios=scenarios_Set2)
#                     experiments_Set3, outcomes_Set3 = evaluator.perform_experiments(scenarios=scenarios_Set3)
#
#
#             # Calculate coefficients of correlation
#             data_Set1 = outcomes[outcome_var][:,-1]
#             data_Set2 = outcomes_Set2[outcome_var][:,-1]
#             data_Set3 = outcomes_Set3[outcome_var][:,-1]
#
#             coefficient_S1_S2 = np.corrcoef(data_Set1,data_Set2)[0][1]
#             coefficient_S1_S3 = np.corrcoef(data_Set1,data_Set3)[0][1]
#
#             # Plot outputs and correlation
#             fig =  plt.figure(figsize=(14,7))
#             ax1 = fig.add_subplot(1,2,1)
#             ax1.plot(data_Set1,data_Set1, color='#39566E')
#             ax1.scatter(data_Set1,data_Set2, color='#8DCCFC')
#             ax1.set_xlabel("Set 1",fontsize=14)
#             ax1.set_ylabel("Set 2",fontsize=14)
#             ax1.tick_params(axis='both', which='major', labelsize=10)
#             ax1.set_title('Set 1 vs Set 2 - ' + str(f) + ' top factors',fontsize=15)
#             ax1.text(0.05,0.95,'R= '+"{0:.3f}".format(coefficient_S1_S2),transform = ax1.transAxes,fontsize=16)
#             ax2 = fig.add_subplot(1,2,2)
#             ax2.plot(data_Set1,data_Set1, color='#39566E')
#             ax2.scatter(data_Set1,data_Set3, color='#FFE0D5')
#             ax2.set_xlabel("Set 1",fontsize=14)
#             ax2.set_ylabel("Set 3",fontsize=14)
#             ax2.tick_params(axis='both', which='major', labelsize=10)
#             ax2.set_title('Set 1 vs Set 3 - ' + str(f) + ' top factors',fontsize=15)
#             ax2.text(0.05,0.95,'R= '+"{0:.3f}".format(coefficient_S1_S3),transform = ax2.transAxes,fontsize=16)
#             plt.savefig('{}/{}_{}_topfactors.png'.format(r'C:/Users/moallemie/EM_analysis/Fig/sa_verification', outcome_var, str(f)),bbox_inches='tight')
#             plt.close()
#
#             n += 1
#
#     n_factor = n
#     return fig, n_factor

# %%
# Run the models for the top n factors in Set 2 and Set 3 and generate correlation figures

def ranking_verification(outcome_var, df_unc2, factors_sorted, X_defaults, X_Set1, X_Set2, X_Set3, outcomes):
    
    from Model_init import vensimModel
    
    coefficient_S1_S2 = 0
    coefficient_S1_S3 = 0.99
    pd_corr = pd.DataFrame(columns=['Outcome', 'Number_of_top_parameters', 'Correlation_Set1_Set3', 'Correlation_Set1_Set2'])

    n = 0    
    for f in range(1, len(factors_sorted)+1):
        ntopfactors = f
        if (coefficient_S1_S2 <=0.99 or coefficient_S1_S3 >= 0.5):

            for i in range(ntopfactors): #Loop through all important factors
                X_Set2[:,factors_sorted[i]] = X_Set1[:,factors_sorted[i]] #Fix use samples for important
                X_Set3[:,factors_sorted[i]] = X_defaults[:,factors_sorted[i]] #Fix important to defaults

            X_Set2_exp = pd.DataFrame(data=X_Set2, columns=df_unc2['Uncertainty'].tolist())
            X_Set3_exp = pd.DataFrame(data=X_Set3, columns=df_unc2['Uncertainty'].tolist())

            scenarios_Set2 = SA_experiments_to_scenarios(X_Set2_exp, df_unc2, model=vensimModel)
            scenarios_Set3 = SA_experiments_to_scenarios(X_Set3_exp, df_unc2, model=vensimModel)
            
            vensimModel.outcomes = [TimeSeriesOutcome(outcome_var)]

            try:
                with MultiprocessingEvaluator(vensimModel, n_processes=nprocess) as evaluator:
                        experiments_Set2, outcomes_Set2 = evaluator.perform_experiments(scenarios=scenarios_Set2)
            except (BrokenPipeError, IOError):
                pass
            
            try:
                with MultiprocessingEvaluator(vensimModel, n_processes=nprocess) as evaluator:
                        experiments_Set3, outcomes_Set3 = evaluator.perform_experiments(scenarios=scenarios_Set3)
            except (BrokenPipeError, IOError):
                pass

            # Calculate coefficients of correlation
            data_Set1 = outcomes[outcome_var][:,-1]
            data_Set2 = outcomes_Set2[outcome_var][:,-1]
            data_Set3 = outcomes_Set3[outcome_var][:,-1]

            coefficient_S1_S2 = np.corrcoef(data_Set1,data_Set2)[0][1]
            coefficient_S1_S3 = np.corrcoef(data_Set1,data_Set3)[0][1]
            
            pd_corr.loc[n] = [outcome_var, ntopfactors, coefficient_S1_S3, coefficient_S1_S2]

            # Plot outputs and correlation
            fig =  plt.figure(figsize=(14,7))
            ax1 = fig.add_subplot(1,2,1)
            ax1.plot(data_Set1,data_Set1, color='#39566E')
            ax1.scatter(data_Set1,data_Set2, color='#8DCCFC')
            ax1.set_xlabel("Set 1",fontsize=14)
            ax1.set_ylabel("Set 2",fontsize=14)
            ax1.tick_params(axis='both', which='major', labelsize=10)
            ax1.set_title('Set 1 vs Set 2 - ' + str(f) + ' top factors',fontsize=15)
            ax1.text(0.05,0.95,'R= '+"{0:.3f}".format(coefficient_S1_S2),transform = ax1.transAxes,fontsize=16)
            ax2 = fig.add_subplot(1,2,2)
            ax2.plot(data_Set1,data_Set1, color='#39566E')
            ax2.scatter(data_Set1,data_Set3, color='#FFE0D5')
            ax2.set_xlabel("Set 1",fontsize=14)
            ax2.set_ylabel("Set 3",fontsize=14)
            ax2.tick_params(axis='both', which='major', labelsize=10)
            ax2.set_title('Set 1 vs Set 3 - ' + str(f) + ' top factors',fontsize=15)
            ax2.text(0.05,0.95,'R= '+"{0:.3f}".format(coefficient_S1_S3),transform = ax2.transAxes,fontsize=16)
            plt.savefig('{}/{}_{}_topfactors.png'.format(r'D:/moallemie/GitHub/Scenario_Modelling/Fig/sa_verification', outcome_var, str(f)),bbox_inches='tight')
            plt.close()

            n += 1
    
    n_factor = n
    return fig, n_factor, pd_corr

# %%
# define the ploting function
def plot_scores(outcome_var, n, sc, t):
    mu_df2 = mu_df.set_index('Uncertainty')
    mu_df2.sort_values(by=['mu_star'], ascending=True, inplace=True)

    sns.set_style('white')
    fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(3, 6)) 
    ind = mu_df2.iloc[:,0]
    err = mu_df2.iloc[:,1]
    ind.plot.barh(xerr=err.values.T,ax=ax, color = ['#D7F0BC']*(20-n)+['#62C890']*n, 
                  ecolor='dimgray', capsize=2,  width=.9)
   
    ax.set_ylabel('')
    ax.legend().set_visible(False)
    ax.set_xlabel('mu_star index', fontsize=12)

    ylabels = ax.get_yticklabels()
    ylabels = [item.get_text()[:-10] for item in ylabels]
    ax.set_yticklabels(ylabels, fontsize=12)
    title = outcome_var[:-10]
    ax.set_title("{}".format(title), fontsize=12)
    plt.suptitle("Target year: "+str(t), y=0.94, fontsize=12)
    plt.rcParams["figure.figsize"] = [7.08,7.3]
    plt.savefig('{}/Morris_ranking_sorted_{}_sc{}_t{}.png'.format(r'D:/moallemie/GitHub/Scenario_Modelling/Fig/sa_verification', outcome_var, sc, t), dpi=300,  bbox_inches='tight')
    return fig

# %%
if __name__ == '__main__':
    
    ema_logging.log_to_stderr(ema_logging.INFO)

    from ema_workbench import (TimeSeriesOutcome, 
                                   perform_experiments,
                                   RealParameter, 
                                   CategoricalParameter,
                                   ema_logging, 
                                   save_results,
                                  load_results)

    
    from ema_workbench import MultiprocessingEvaluator

    out_dir = 'D:/moallemie/GitHub/Scenario_Modelling/Model/'
    df_out = pd.read_excel(out_dir+'ScenarioFramework.xlsx', sheet_name='Outcomes')
    outcome_vars = ['Total Population Indicator',
                     'Total Primary Education Graduates Indicator',
                     'Total Secondary Education Graduates Indicator',
                     'Total Tertiary Education Graduates Indicator',
                     'GWP per Capita Indicator',
                     'Energy Demand Indicator',
                     'Solar Energy Production Indicator',
                     'Wind Energy Production Indicator',
                     'Biomass Energy Production Indicator',
                     'Oil Production Indicator',
                     'Gas Production Indicator',
                     'Coal Production Indicator',
                     'Total Croplands Indicator',
                     'Forest Land Indicator',
                     'Pasture Land Indicator',
                     'Urban Industrial Land Indicator',
                     'Nonenergy Crops Production Indicator',
                     'Livestock Production Indicator',
                     'Total CO2 Emissions Indicator',
                     'CO2 Radiative Forcing Indicator']


    import  time
    start = time.time()

    top_factors = {}
    pd_corr = pd.DataFrame(columns=['Outcome', 'Number_of_top_parameters', 'Correlation_Set1_Set3', 'Correlation_Set1_Set2'])

    for out, outcome_var in enumerate(outcome_vars):
        ema_logging.log_to_stderr(ema_logging.INFO)
        df_unc2, factors_sorted, X_defaults, X_Set1, X_Set2, X_Set3, outcomes, mu_df = create_sets(outcome_var)
        fig, n_factor, pd_corr_var = ranking_verification(outcome_var, df_unc2, factors_sorted, X_defaults, X_Set1, X_Set2, X_Set3, outcomes)
        plot_scores(outcome_var, n_factor, sc, t)
        plt.close()

        top_factors[outcome_var] = n_factor
        pd_corr = pd.concat([pd_corr, pd_corr_var])
        
    import json
    with open('D:/moallemie/GitHub/Scenario_Modelling/Fig/sa_verification/note.txt', 'w') as file:
         file.write(json.dumps(top_factors))

    end = time.time()
    print("took {} seconds".format(end-start))
# Out:
# [MainProcess/INFO] using 64 bit vensim
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# ...
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 2000 scenarios * 1 policies * 1 model(s) = 2000 experiments
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] 400 cases completed
# [MainProcess/INFO] 600 cases completed
# [MainProcess/INFO] 800 cases completed
# [MainProcess/INFO] 1000 cases completed
# [MainProcess/INFO] 1200 cases completed
# [MainProcess/INFO] 1400 cases completed
# [MainProcess/INFO] 1600 cases completed
# [MainProcess/INFO] 1800 cases completed
# [MainProcess/INFO] 2000 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool
# D:\moallemie\Anaconda\lib\site-packages\numpy\lib\function_base.py:2534: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# D:\moallemie\Anaconda\lib\site-packages\numpy\lib\function_base.py:2535: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# took 272334.51307344437 seconds

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(pd_corr)
# Out:
#                                           Outcome Number_of_top_parameters  \
# 0                      Total Population Indicator                        1
# 1                      Total Population Indicator                        2
# 2                      Total Population Indicator                        3
# 3                      Total Population Indicator                        4
# 4                      Total Population Indicator                        5
# 5                      Total Population Indicator                        6
# 6                      Total Population Indicator                        7
# 7                      Total Population Indicator                        8
# 8                      Total Population Indicator                        9
# 9                      Total Population Indicator                       10
# 10                     Total Population Indicator                       11
# 11                     Total Population Indicator                       12
# 12                     Total Population Indicator                       13
# 0     Total Primary Education Graduates Indicator                        1
# 1     Total Primary Education Graduates Indicator                        2
# 2     Total Primary Education Graduates Indicator                        3
# 3     Total Primary Education Graduates Indicator                        4
# 4     Total Primary Education Graduates Indicator                        5
# 5     Total Primary Education Graduates Indicator                        6
# 6     Total Primary Education Graduates Indicator                        7
# 7     Total Primary Education Graduates Indicator                        8
# 8     Total Primary Education Graduates Indicator                        9
# 9     Total Primary Education Graduates Indicator                       10
# 10    Total Primary Education Graduates Indicator                       11
# 11    Total Primary Education Graduates Indicator                       12
# 12    Total Primary Education Graduates Indicator                       13
# 13    Total Primary Education Graduates Indicator                       14
# 14    Total Primary Education Graduates Indicator                       15
# 15    Total Primary Education Graduates Indicator                       16
# 16    Total Primary Education Graduates Indicator                       17
# 17    Total Primary Education Graduates Indicator                       18
# 18    Total Primary Education Graduates Indicator                       19
# 0   Total Secondary Education Graduates Indicator                        1
# 1   Total Secondary Education Graduates Indicator                        2
# 2   Total Secondary Education Graduates Indicator                        3
# 3   Total Secondary Education Graduates Indicator                        4
# 4   Total Secondary Education Graduates Indicator                        5
# 5   Total Secondary Education Graduates Indicator                        6
# 6   Total Secondary Education Graduates Indicator                        7
# 7   Total Secondary Education Graduates Indicator                        8
# 8   Total Secondary Education Graduates Indicator                        9
# 9   Total Secondary Education Graduates Indicator                       10
# 10  Total Secondary Education Graduates Indicator                       11
# 11  Total Secondary Education Graduates Indicator                       12
# 12  Total Secondary Education Graduates Indicator                       13
# 13  Total Secondary Education Graduates Indicator                       14
# 14  Total Secondary Education Graduates Indicator                       15
# 15  Total Secondary Education Graduates Indicator                       16
# 16  Total Secondary Education Graduates Indicator                       17
# 0    Total Tertiary Education Graduates Indicator                        1
# 1    Total Tertiary Education Graduates Indicator                        2
# 2    Total Tertiary Education Graduates Indicator                        3
# 3    Total Tertiary Education Graduates Indicator                        4
# 4    Total Tertiary Education Graduates Indicator                        5
# 5    Total Tertiary Education Graduates Indicator                        6
# 6    Total Tertiary Education Graduates Indicator                        7
# 7    Total Tertiary Education Graduates Indicator                        8
# 8    Total Tertiary Education Graduates Indicator                        9
# 9    Total Tertiary Education Graduates Indicator                       10
# 10   Total Tertiary Education Graduates Indicator                       11
# 11   Total Tertiary Education Graduates Indicator                       12
# 12   Total Tertiary Education Graduates Indicator                       13
# 13   Total Tertiary Education Graduates Indicator                       14
# 14   Total Tertiary Education Graduates Indicator                       15
# 15   Total Tertiary Education Graduates Indicator                       16
# 16   Total Tertiary Education Graduates Indicator                       17
# 17   Total Tertiary Education Graduates Indicator                       18
# 0                        GWP per Capita Indicator                        1
# 1                        GWP per Capita Indicator                        2
# 2                        GWP per Capita Indicator                        3
# 3                        GWP per Capita Indicator                        4
# 4                        GWP per Capita Indicator                        5
# 5                        GWP per Capita Indicator                        6
# 6                        GWP per Capita Indicator                        7
# 7                        GWP per Capita Indicator                        8
# 8                        GWP per Capita Indicator                        9
# 9                        GWP per Capita Indicator                       10
# 10                       GWP per Capita Indicator                       11
# 11                       GWP per Capita Indicator                       12
# 12                       GWP per Capita Indicator                       13
# 13                       GWP per Capita Indicator                       14
# 14                       GWP per Capita Indicator                       15
# 15                       GWP per Capita Indicator                       16
# 16                       GWP per Capita Indicator                       17
# 17                       GWP per Capita Indicator                       18
# 18                       GWP per Capita Indicator                       19
# 19                       GWP per Capita Indicator                       20
# 0                         Energy Demand Indicator                        1
# 1                         Energy Demand Indicator                        2
# 2                         Energy Demand Indicator                        3
# 3                         Energy Demand Indicator                        4
# 4                         Energy Demand Indicator                        5
# 5                         Energy Demand Indicator                        6
# 6                         Energy Demand Indicator                        7
# 7                         Energy Demand Indicator                        8
# 8                         Energy Demand Indicator                        9
# 9                         Energy Demand Indicator                       10
# 10                        Energy Demand Indicator                       11
# 11                        Energy Demand Indicator                       12
# 12                        Energy Demand Indicator                       13
# 13                        Energy Demand Indicator                       14
# 14                        Energy Demand Indicator                       15
# 15                        Energy Demand Indicator                       16
# 16                        Energy Demand Indicator                       17
# 17                        Energy Demand Indicator                       18
# 18                        Energy Demand Indicator                       19
# 19                        Energy Demand Indicator                       20
# 0               Solar Energy Production Indicator                        1
# 1               Solar Energy Production Indicator                        2
# 2               Solar Energy Production Indicator                        3
# 3               Solar Energy Production Indicator                        4
# 4               Solar Energy Production Indicator                        5
# 5               Solar Energy Production Indicator                        6
# 6               Solar Energy Production Indicator                        7
# 7               Solar Energy Production Indicator                        8
# 8               Solar Energy Production Indicator                        9
# 9               Solar Energy Production Indicator                       10
# 10              Solar Energy Production Indicator                       11
# 11              Solar Energy Production Indicator                       12
# 12              Solar Energy Production Indicator                       13
# 13              Solar Energy Production Indicator                       14
# 14              Solar Energy Production Indicator                       15
# 15              Solar Energy Production Indicator                       16
# 16              Solar Energy Production Indicator                       17
# 17              Solar Energy Production Indicator                       18
# 18              Solar Energy Production Indicator                       19
# 19              Solar Energy Production Indicator                       20
# 0                Wind Energy Production Indicator                        1
# 1                Wind Energy Production Indicator                        2
# 2                Wind Energy Production Indicator                        3
# 3                Wind Energy Production Indicator                        4
# 4                Wind Energy Production Indicator                        5
# 5                Wind Energy Production Indicator                        6
# 6                Wind Energy Production Indicator                        7
# 7                Wind Energy Production Indicator                        8
# 8                Wind Energy Production Indicator                        9
# 9                Wind Energy Production Indicator                       10
# 10               Wind Energy Production Indicator                       11
# 11               Wind Energy Production Indicator                       12
# 12               Wind Energy Production Indicator                       13
# 13               Wind Energy Production Indicator                       14
# 14               Wind Energy Production Indicator                       15
# 15               Wind Energy Production Indicator                       16
# 16               Wind Energy Production Indicator                       17
# 17               Wind Energy Production Indicator                       18
# 18               Wind Energy Production Indicator                       19
# 19               Wind Energy Production Indicator                       20
# 0             Biomass Energy Production Indicator                        1
# 1             Biomass Energy Production Indicator                        2
# 2             Biomass Energy Production Indicator                        3
# 3             Biomass Energy Production Indicator                        4
# 4             Biomass Energy Production Indicator                        5
# 5             Biomass Energy Production Indicator                        6
# 6             Biomass Energy Production Indicator                        7
# 7             Biomass Energy Production Indicator                        8
# 8             Biomass Energy Production Indicator                        9
# 9             Biomass Energy Production Indicator                       10
# 10            Biomass Energy Production Indicator                       11
# 11            Biomass Energy Production Indicator                       12
# 12            Biomass Energy Production Indicator                       13
# 13            Biomass Energy Production Indicator                       14
# 14            Biomass Energy Production Indicator                       15
# 15            Biomass Energy Production Indicator                       16
# 16            Biomass Energy Production Indicator                       17
# 17            Biomass Energy Production Indicator                       18
# 18            Biomass Energy Production Indicator                       19
# 19            Biomass Energy Production Indicator                       20
# 0                        Oil Production Indicator                        1
# 1                        Oil Production Indicator                        2
# 2                        Oil Production Indicator                        3
# 3                        Oil Production Indicator                        4
# 4                        Oil Production Indicator                        5
# 5                        Oil Production Indicator                        6
# 6                        Oil Production Indicator                        7
# 7                        Oil Production Indicator                        8
# 8                        Oil Production Indicator                        9
# 9                        Oil Production Indicator                       10
# 10                       Oil Production Indicator                       11
# 11                       Oil Production Indicator                       12
# 12                       Oil Production Indicator                       13
# 13                       Oil Production Indicator                       14
# 14                       Oil Production Indicator                       15
# 15                       Oil Production Indicator                       16
# 16                       Oil Production Indicator                       17
# 17                       Oil Production Indicator                       18
# 18                       Oil Production Indicator                       19
# 19                       Oil Production Indicator                       20
# 0                        Gas Production Indicator                        1
# 1                        Gas Production Indicator                        2
# 2                        Gas Production Indicator                        3
# 3                        Gas Production Indicator                        4
# 4                        Gas Production Indicator                        5
# 5                        Gas Production Indicator                        6
# 6                        Gas Production Indicator                        7
# 7                        Gas Production Indicator                        8
# 8                        Gas Production Indicator                        9
# 9                        Gas Production Indicator                       10
# 10                       Gas Production Indicator                       11
# 11                       Gas Production Indicator                       12
# 12                       Gas Production Indicator                       13
# 13                       Gas Production Indicator                       14
# 14                       Gas Production Indicator                       15
# 15                       Gas Production Indicator                       16
# 16                       Gas Production Indicator                       17
# 17                       Gas Production Indicator                       18
# 18                       Gas Production Indicator                       19
# 19                       Gas Production Indicator                       20
# 0                       Coal Production Indicator                        1
# 1                       Coal Production Indicator                        2
# 2                       Coal Production Indicator                        3
# 3                       Coal Production Indicator                        4
# 4                       Coal Production Indicator                        5
# 5                       Coal Production Indicator                        6
# 6                       Coal Production Indicator                        7
# 7                       Coal Production Indicator                        8
# 8                       Coal Production Indicator                        9
# 9                       Coal Production Indicator                       10
# 10                      Coal Production Indicator                       11
# 11                      Coal Production Indicator                       12
# 12                      Coal Production Indicator                       13
# 13                      Coal Production Indicator                       14
# 14                      Coal Production Indicator                       15
# 15                      Coal Production Indicator                       16
# 16                      Coal Production Indicator                       17
# 17                      Coal Production Indicator                       18
# 18                      Coal Production Indicator                       19
# 19                      Coal Production Indicator                       20
# 0                       Total Croplands Indicator                        1
# 1                       Total Croplands Indicator                        2
# 2                       Total Croplands Indicator                        3
# 3                       Total Croplands Indicator                        4
# 4                       Total Croplands Indicator                        5
# 5                       Total Croplands Indicator                        6
# 6                       Total Croplands Indicator                        7
# 7                       Total Croplands Indicator                        8
# 8                       Total Croplands Indicator                        9
# 9                       Total Croplands Indicator                       10
# 10                      Total Croplands Indicator                       11
# 11                      Total Croplands Indicator                       12
# 12                      Total Croplands Indicator                       13
# 13                      Total Croplands Indicator                       14
# 14                      Total Croplands Indicator                       15
# 15                      Total Croplands Indicator                       16
# 16                      Total Croplands Indicator                       17
# 17                      Total Croplands Indicator                       18
# 18                      Total Croplands Indicator                       19
# 19                      Total Croplands Indicator                       20
# 0                           Forest Land Indicator                        1
# 1                           Forest Land Indicator                        2
# 2                           Forest Land Indicator                        3
# 3                           Forest Land Indicator                        4
# 4                           Forest Land Indicator                        5
# 5                           Forest Land Indicator                        6
# 6                           Forest Land Indicator                        7
# 7                           Forest Land Indicator                        8
# 8                           Forest Land Indicator                        9
# 9                           Forest Land Indicator                       10
# 10                          Forest Land Indicator                       11
# 11                          Forest Land Indicator                       12
# 12                          Forest Land Indicator                       13
# 13                          Forest Land Indicator                       14
# 14                          Forest Land Indicator                       15
# 15                          Forest Land Indicator                       16
# 0                          Pasture Land Indicator                        1
# 1                          Pasture Land Indicator                        2
# 2                          Pasture Land Indicator                        3
# 3                          Pasture Land Indicator                        4
# 4                          Pasture Land Indicator                        5
# 5                          Pasture Land Indicator                        6
# 6                          Pasture Land Indicator                        7
# 7                          Pasture Land Indicator                        8
# 8                          Pasture Land Indicator                        9
# 9                          Pasture Land Indicator                       10
# 10                         Pasture Land Indicator                       11
# 11                         Pasture Land Indicator                       12
# 12                         Pasture Land Indicator                       13
# 13                         Pasture Land Indicator                       14
# 14                         Pasture Land Indicator                       15
# 15                         Pasture Land Indicator                       16
# 16                         Pasture Land Indicator                       17
# 17                         Pasture Land Indicator                       18
# 18                         Pasture Land Indicator                       19
# 19                         Pasture Land Indicator                       20
# 0                 Urban Industrial Land Indicator                        1
# 1                 Urban Industrial Land Indicator                        2
# 2                 Urban Industrial Land Indicator                        3
# 3                 Urban Industrial Land Indicator                        4
# 4                 Urban Industrial Land Indicator                        5
# 5                 Urban Industrial Land Indicator                        6
# 6                 Urban Industrial Land Indicator                        7
# 7                 Urban Industrial Land Indicator                        8
# 8                 Urban Industrial Land Indicator                        9
# 9                 Urban Industrial Land Indicator                       10
# 10                Urban Industrial Land Indicator                       11
# 11                Urban Industrial Land Indicator                       12
# 12                Urban Industrial Land Indicator                       13
# 13                Urban Industrial Land Indicator                       14
# 14                Urban Industrial Land Indicator                       15
# 15                Urban Industrial Land Indicator                       16
# 16                Urban Industrial Land Indicator                       17
# 17                Urban Industrial Land Indicator                       18
# 18                Urban Industrial Land Indicator                       19
# 19                Urban Industrial Land Indicator                       20
# 0            Nonenergy Crops Production Indicator                        1
# 1            Nonenergy Crops Production Indicator                        2
# 2            Nonenergy Crops Production Indicator                        3
# 3            Nonenergy Crops Production Indicator                        4
# 4            Nonenergy Crops Production Indicator                        5
# 5            Nonenergy Crops Production Indicator                        6
# 6            Nonenergy Crops Production Indicator                        7
# 7            Nonenergy Crops Production Indicator                        8
# 8            Nonenergy Crops Production Indicator                        9
# 9            Nonenergy Crops Production Indicator                       10
# 10           Nonenergy Crops Production Indicator                       11
# 11           Nonenergy Crops Production Indicator                       12
# 12           Nonenergy Crops Production Indicator                       13
# 13           Nonenergy Crops Production Indicator                       14
# 14           Nonenergy Crops Production Indicator                       15
# 15           Nonenergy Crops Production Indicator                       16
# 16           Nonenergy Crops Production Indicator                       17
# 0                  Livestock Production Indicator                        1
# 1                  Livestock Production Indicator                        2
# 2                  Livestock Production Indicator                        3
# 3                  Livestock Production Indicator                        4
# 4                  Livestock Production Indicator                        5
# 5                  Livestock Production Indicator                        6
# 6                  Livestock Production Indicator                        7
# 7                  Livestock Production Indicator                        8
# 8                  Livestock Production Indicator                        9
# 9                  Livestock Production Indicator                       10
# 10                 Livestock Production Indicator                       11
# 11                 Livestock Production Indicator                       12
# 12                 Livestock Production Indicator                       13
# 13                 Livestock Production Indicator                       14
# 14                 Livestock Production Indicator                       15
# 15                 Livestock Production Indicator                       16
# 0                   Total CO2 Emissions Indicator                        1
# 1                   Total CO2 Emissions Indicator                        2
# 2                   Total CO2 Emissions Indicator                        3
# 3                   Total CO2 Emissions Indicator                        4
# 4                   Total CO2 Emissions Indicator                        5
# 5                   Total CO2 Emissions Indicator                        6
# 6                   Total CO2 Emissions Indicator                        7
# 7                   Total CO2 Emissions Indicator                        8
# 8                   Total CO2 Emissions Indicator                        9
# 9                   Total CO2 Emissions Indicator                       10
# 10                  Total CO2 Emissions Indicator                       11
# 11                  Total CO2 Emissions Indicator                       12
# 12                  Total CO2 Emissions Indicator                       13
# 13                  Total CO2 Emissions Indicator                       14
# 14                  Total CO2 Emissions Indicator                       15
# 15                  Total CO2 Emissions Indicator                       16
# 16                  Total CO2 Emissions Indicator                       17
# 17                  Total CO2 Emissions Indicator                       18
# 18                  Total CO2 Emissions Indicator                       19
# 19                  Total CO2 Emissions Indicator                       20
# 0                 CO2 Radiative Forcing Indicator                        1
# 1                 CO2 Radiative Forcing Indicator                        2
# 2                 CO2 Radiative Forcing Indicator                        3
# 3                 CO2 Radiative Forcing Indicator                        4
# 4                 CO2 Radiative Forcing Indicator                        5
# 5                 CO2 Radiative Forcing Indicator                        6
# 6                 CO2 Radiative Forcing Indicator                        7
# 7                 CO2 Radiative Forcing Indicator                        8
# 8                 CO2 Radiative Forcing Indicator                        9
# 9                 CO2 Radiative Forcing Indicator                       10
# 10                CO2 Radiative Forcing Indicator                       11
# 11                CO2 Radiative Forcing Indicator                       12
# 12                CO2 Radiative Forcing Indicator                       13
# 13                CO2 Radiative Forcing Indicator                       14
# 14                CO2 Radiative Forcing Indicator                       15
# 15                CO2 Radiative Forcing Indicator                       16
# 16                CO2 Radiative Forcing Indicator                       17
# 17                CO2 Radiative Forcing Indicator                       18
# 18                CO2 Radiative Forcing Indicator                       19
# 19                CO2 Radiative Forcing Indicator                       20
#
#     Correlation_Set1_Set3  Correlation_Set1_Set2
# 0                0.796732               0.602060
# 1                0.472579               0.886487
# 2                0.465938               0.889934
# 3                0.428209               0.907752
# 4                0.421604               0.908302
# 5                0.420702               0.908912
# 6                0.420727               0.909021
# 7                0.420779               0.909014
# 8                0.391245               0.918922
# 9                0.286047               0.956745
# 10               0.286007               0.956916
# 11               0.281280               0.959695
# 12               0.018836               0.999883
# 0                0.823296               0.559939
# 1                0.748785               0.623962
# 2                0.745033               0.628970
# 3                0.710703               0.674733
# 4                0.478590               0.858490
# 5                0.404273               0.891235
# 6                0.317265               0.932764
# 7                0.315605               0.933230
# 8                0.315585               0.933193
# 9                0.279844               0.946718
# 10               0.279830               0.946716
# 11               0.280288               0.948429
# 12               0.278533               0.951093
# 13               0.226264               0.971529
# 14               0.226306               0.971558
# 15               0.226213               0.971568
# 16               0.186865               0.977822
# 17               0.188325               0.977772
# 18               0.027230               0.999966
# 0                0.963451               0.238545
# 1                0.737312               0.657128
# 2                0.670977               0.719535
# 3                0.632671               0.752668
# 4                0.626374               0.758632
# 5                0.624720               0.760292
# 6                0.287158               0.955865
# 7                0.248282               0.965188
# 8                0.248456               0.965274
# 9                0.246432               0.966816
# 10               0.246326               0.966813
# 11               0.241431               0.969326
# 12               0.241340               0.969451
# 13               0.216562               0.976861
# 14               0.216565               0.976829
# 15               0.216061               0.976895
# 16               0.006171               0.999931
# 0                0.920927               0.366134
# 1                0.866264               0.460541
# 2                0.635850               0.745420
# 3                0.600639               0.783104
# 4                0.579441               0.804104
# 5                0.570379               0.809131
